# %%
import rasterio as rio
import decorrelate

with rio.open('test_despeckle.tif') as src:
  img = src.read()

# %%
decorrelate.inspect_spectrum(img)

# %%
decorrelate.decorrelate(img, 'output.mat', -1, -1, 0.5, 0.5, 50)
# Out:
# /home/jp/.local/lib/python3.8/site-packages/numpy/lib/polynomial.py:666: RuntimeWarning: overflow encountered in multiply
#   scale = NX.sqrt((lhs*lhs).sum(axis=0))
# /home/jp/.local/lib/python3.8/site-packages/numpy/core/_methods.py:49: RuntimeWarning: overflow encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
# /home/jp/Documents/IME/TCC/CODE/speckle2void/Decorrelation/decorrelate.py:36: RankWarning: Polyfit may be poorly conditioned
#   cout, W = equalizeIQ(img_complex_new, m_x, m_y, f_x, f_y)
# /home/jp/Documents/IME/TCC/CODE/speckle2void/Decorrelation/decorrelate.py:36: RankWarning: Polyfit may be poorly conditioned
#   cout, W = equalizeIQ(img_complex_new, m_x, m_y, f_x, f_y)
# /home/jp/Documents/IME/TCC/CODE/speckle2void/Decorrelation/decorrelate.py:102: RuntimeWarning: divide by zero encountered in divide
#   W = 1 / G / np.sqrt(np.sum(mask.flatten()))
